# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
from test_cases.test_paths import *
from test_cases.test_bronze import *
from test_cases.test_silver import *
from test_cases.test_gold import *
from test_cases.test_end_to_end import *

test_bronze_paths_exist(spark)
test_silver_paths_exist(spark)
test_gold_paths_exist(spark)

test_bronze_customers_not_empty(spark)
test_bronze_orders_not_empty(spark)

test_customers_no_null_ids(spark)
test_orders_no_duplicate_ids(spark)
test_customer_region_schema(spark)

test_gold_orders_by_region_exists(spark)
test_gold_columns(spark)

test_order_count_reconciliation(spark)
test_sales_reconciliation(spark)

print("✅ ALL TESTS PASSED")
