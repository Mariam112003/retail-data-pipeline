# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
from retail_orders.bronze.bronze_ingestion import run_bronze
from retail_orders.silver.silver_transform import run_silver
from retail_orders.gold.gold_analytics import run_gold

# %%
dbutils.fs.rm(
    "/Volumes/workspace/default/pipeine/silver/customer_region",
    recurse=True
)

run_gold(spark)

# %%
run_bronze(spark)

# %%
run_silver(spark)

# %%
run_gold(spark)
